# %%
import pandas as pd

# %%
df = pd.read_csv("green_tripdata_2019-09.csv.gz",low_memory=False)
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-09-01 00:10:53   2019-09-01 00:23:46
# 1            2.0  2019-09-01 00:31:22   2019-09-01 00:44:37
# 2            2.0  2019-09-01 00:50:24   2019-09-01 01:03:20
# 3            2.0  2019-09-01 00:27:06   2019-09-01 00:33:22
# 4            2.0  2019-09-01 00:43:23   2019-09-01 00:59:54
# ...          ...                  ...                   ...
# 449058       NaN  2019-09-30 23:13:00   2019-09-30 23:41:00
# 449059       NaN  2019-09-30 23:26:00   2019-09-30 23:46:00
# 449060       NaN  2019-09-30 23:15:00   2019-09-30 23:43:00
# 449061       NaN  2019-09-30 23:19:00   2019-10-01 00:06:00
# 449062       NaN  2019-09-30 23:35:00   2019-09-30 23:58:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0            65           189
# 1                       N         1.0            97           225
# ...

# %%
df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])
df['lpep_dropoff_datetime'] = pd.to_datetime(df['lpep_dropoff_datetime'])

# %%
df[(df['lpep_pickup_datetime'].dt.date==pd.to_datetime('2019-09-18')) & (df['lpep_dropoff_datetime'].dt.date==pd.to_datetime('2019-09-18'))]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 217634       2.0  2019-09-18 09:12:39   2019-09-18 09:20:14
# 218133       2.0  2019-09-18 10:05:23   2019-09-18 10:12:42
# 218134       2.0  2019-09-18 10:53:43   2019-09-18 11:00:01
# 218254       2.0  2019-09-18 00:02:54   2019-09-18 00:08:54
# 218281       2.0  2019-09-18 00:03:40   2019-09-18 00:23:29
# ...          ...                  ...                   ...
# 423824       NaN  2019-09-18 23:10:00   2019-09-18 23:28:00
# 423825       NaN  2019-09-18 23:18:00   2019-09-18 23:59:00
# 423828       NaN  2019-09-18 23:00:00   2019-09-18 23:15:00
# 423830       NaN  2019-09-18 23:19:00   2019-09-18 23:34:00
# 423831       NaN  2019-09-18 23:04:00   2019-09-18 23:14:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 217634                  N         1.0            95           134
# 218133                  N         1.0            95           196
# ...

# %%
max_index = df['trip_distance'].idxmax()
row_with_max = df.loc[max_index]
row_with_max
# Out:
# VendorID                                 2.0
# lpep_pickup_datetime     2019-09-26 19:32:52
# lpep_dropoff_datetime    2019-09-27 01:50:27
# store_and_fwd_flag                         N
# RatecodeID                               4.0
# PULocationID                             265
# DOLocationID                              16
# passenger_count                          1.0
# trip_distance                         341.64
# fare_amount                           1761.0
# extra                                    1.0
# mta_tax                                  0.5
# tip_amount                               0.0
# tolls_amount                             0.0
# ehail_fee                                NaN
# improvement_surcharge                    0.3
# total_amount                          1762.8
# payment_type                             2.0
# trip_type                                1.0
# congestion_surcharge                     0.0
# Name: 337292, dtype: object

# %%
taxi_zone_lookup = pd.read_csv("taxi+_zone_lookup.csv")
taxi_zone_lookup
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
taxi_zone_lookup = pd.read_csv("taxi+_zone_lookup.csv")
taxi_zone_lookup.rename(columns={'LocationID': 'PULocationID'}, inplace=True)
taxi_zone_lookup=taxi_zone_lookup[['PULocationID','Borough','Zone']][taxi_zone_lookup['Borough']!='Unknown']
final_df = pd.merge(df, taxi_zone_lookup, on='PULocationID', how='left')
final_df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-09-01 00:10:53   2019-09-01 00:23:46
# 1            2.0  2019-09-01 00:31:22   2019-09-01 00:44:37
# 2            2.0  2019-09-01 00:50:24   2019-09-01 01:03:20
# 3            2.0  2019-09-01 00:27:06   2019-09-01 00:33:22
# 4            2.0  2019-09-01 00:43:23   2019-09-01 00:59:54
# ...          ...                  ...                   ...
# 449058       NaN  2019-09-30 23:13:00   2019-09-30 23:41:00
# 449059       NaN  2019-09-30 23:26:00   2019-09-30 23:46:00
# 449060       NaN  2019-09-30 23:15:00   2019-09-30 23:43:00
# 449061       NaN  2019-09-30 23:19:00   2019-10-01 00:06:00
# 449062       NaN  2019-09-30 23:35:00   2019-09-30 23:58:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0            65           189
# 1                       N         1.0            97           225
# ...

# %%
final_df= final_df[(final_df['lpep_pickup_datetime'].dt.month==9) & (final_df['lpep_pickup_datetime'].dt.year==2019) &(final_df['Zone']=='Astoria')]
final_df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 5            2.0  2019-09-01 00:55:37   2019-09-01 01:17:02
# 15           1.0  2019-09-01 00:35:43   2019-09-01 00:47:21
# 20           2.0  2019-09-01 00:58:19   2019-09-01 01:07:00
# 44           2.0  2019-09-01 00:15:10   2019-09-01 00:18:22
# 45           2.0  2019-09-01 00:21:37   2019-09-01 00:33:31
# ...          ...                  ...                   ...
# 448477       NaN  2019-09-30 14:26:00   2019-09-30 15:03:00
# 448546       NaN  2019-09-30 15:00:00   2019-09-30 15:29:00
# 448578       NaN  2019-09-30 15:22:00   2019-09-30 15:51:00
# 448977       NaN  2019-09-30 20:17:00   2019-09-30 20:56:00
# 448992       NaN  2019-09-30 21:30:00   2019-09-30 21:51:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 5                       N         1.0             7            41
# 15                      N         1.0             7            83
# ...

# %%
max_index = final_df['tip_amount'].idxmax()
row_with_max = final_df.loc[max_index]
row_with_max
# Out:
# VendorID                                 2.0
# lpep_pickup_datetime     2019-09-08 18:10:40
# lpep_dropoff_datetime    2019-09-08 18:44:42
# store_and_fwd_flag                         N
# RatecodeID                               1.0
# PULocationID                               7
# DOLocationID                             132
# passenger_count                          1.0
# trip_distance                          14.05
# fare_amount                             40.0
# extra                                    0.0
# mta_tax                                  0.5
# tip_amount                             62.31
# tolls_amount                             0.0
# ehail_fee                                NaN
# improvement_surcharge                    0.3
# total_amount                          103.11
# payment_type                             1.0
# trip_type                                1.0
# congestion_surcharge                     0.0
# Borough                               Queens
# ...

# %%
taxi_zone_lookup[taxi_zone_lookup['LocationID']==132]
# Out:
#      LocationID Borough         Zone service_zone
# 131         132  Queens  JFK Airport     Airports

# %%
full_df = pd.merge(df1, df2, on='ID', how='left')

# %%
quest_3 = df[(df['lpep_pickup_datetime'].dt.date==pd.to_datetime('2019-09-18')) &

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://root:root@localhost:5432/ny_taxi")
engine.connect()

# %%
# %time df.to_sql('yellow_taxi_data', engine, chunksize=100000, method='multi',if_exists='replace')

# %%
print(pd.io.sql.get_schema(df,name='yellow_taxi_data',con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" FLOAT(53),
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" FLOAT(53),
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type FLOAT(53),
# 	trip_type FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )
